# %% [markdown]
# # Jiu Jitsu Analysis

# %%
from matplotlib import image
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
data_path = "/mnt/data/jiu_jitsu"
labels_path = f"{data_path}/labels/annotations.json"
images_path = f"{data_path}/images/"
img_names_path = f"{data_path}/imgs.txt"

# %%
f = open(labels_path)
data = json.load(f)
data[0:1]
# Out:
# [{'position': 'standing',
#   'image': '0000001',
#   'frame': 1,
#   'pose2': [[449.349365234375, 223.6246337890625, 0.9949263334274292],
#    [456.9615478515625, 216.42767333984375, 0.9282947778701782],
#    [444.4251708984375, 216.02813720703125, 0.9518612623214722],
#    [466.9593505859375, 223.40911865234375, 0.9214688539505005],
#    [434.8798828125, 220.47491455078125, 0.8109962940216064],
#    [485.706298828125, 265.40643310546875, 0.993882417678833],
#    [416.6734619140625, 255.49859619140625, 0.9333498477935791],
#    [498.40576171875, 317.318603515625, 0.9748102426528931],
#    [384.27294921875, 281.30487060546875, 0.8125534057617188],
#    [504.601806640625, 362.6763916015625, 1.0643349885940552],
#    [391.1412353515625, 275.41064453125, 0.69492506980896],
#    [459.853759765625, 368.930908203125, 0.8875435590744019],
#    [417.650634765625, 358.8580322265625, 0.97788405418396],
#    [462.1832275390625, 449.27325439453125, 0.93451988697052],
# ...

# %%
print(f"{images_path}0000001.jpg")
# Out:
# /mnt/data/jiu_jitsu/images/0000001.jpg

# %%
# Open image
from PIL import Image       

initial_pic_path = f"{images_path}0000001.jpg"

# TODO: Fix reading path for any image using f-strings ideally. 

img = Image.open(initial_pic_path)
# img.show()

# %%
# Plot poses on top of single image
pose_list = data[0]['pose2']
pose = np.array(pose_list)
pose
# Out:
# array([[449.34936523, 223.62463379,   0.99492633],
#        [456.96154785, 216.42767334,   0.92829478],
#        [444.4251709 , 216.02813721,   0.95186126],
#        [466.95935059, 223.40911865,   0.92146885],
#        [434.87988281, 220.47491455,   0.81099629],
#        [485.70629883, 265.40643311,   0.99388242],
#        [416.67346191, 255.49859619,   0.93334985],
#        [498.40576172, 317.31860352,   0.97481024],
#        [384.27294922, 281.30487061,   0.81255341],
#        [504.60180664, 362.6763916 ,   1.06433499],
#        [391.14123535, 275.41064453,   0.69492507],
#        [459.85375977, 368.9309082 ,   0.88754356],
#        [417.65063477, 358.85803223,   0.97788405],
#        [462.18322754, 449.27325439,   0.93451989],
#        [417.57189941, 445.04217529,   0.83721244],
#        [451.78662109, 545.20214844,   0.74557877],
#        [415.68884277, 539.74212646,   0.6409514 ]])

# %%
x_coordinates = np.array([(p[0]) for p in pose])
y_coordinates = np.array([(p[1]) for p in pose])
# print(x_coordinates, y_coordinates)

# %%
plt.scatter(x_coordinates, y_coordinates)

# %%
data = image.imread(initial_pic_path)
plt.imshow(data)
plt.scatter(x_coordinates, y_coordinates)
plt.show()
